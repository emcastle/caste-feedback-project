# %%
import pandas as pd

# %% [markdown]
# confirm the path to the csv

# %%
from pathlib import Path

fp = Path("../data/_final_master/feedback_entries.csv")
print(fp.resolve())
print(fp.exists())
print(fp.stat().st_size / (1024**2), "MB")
# Out:
# C:\Users\caste341\Desktop\caste-feedback-project\data\_final_master\feedback_entries.csv
# True
# 38.334031105041504 MB

# %% [markdown]
# read in the csv as a df

# %%
feedback_entries_df = pd.read_csv("../data/_final_master/feedback_entries.csv")

# %% [markdown]
# peek into the df

# %%
feedback_entries_df.head(10)
# Out:
#                                               doc_id  \
# 0  da1b26ac8b25f76d283b19739700d09f2da6b63422cc0b...
# 1  19caac64e7877c04e034145d0fa98f7e5ba9c5a775cf62...
# 2  19caac64e7877c04e034145d0fa98f7e5ba9c5a775cf62...
# 3  19caac64e7877c04e034145d0fa98f7e5ba9c5a775cf62...
# 4  76094ce75fe87db08c28689f0fb1da94f3d06c52aa1aa9...
# 5  76094ce75fe87db08c28689f0fb1da94f3d06c52aa1aa9...
# 6  76094ce75fe87db08c28689f0fb1da94f3d06c52aa1aa9...
# 7  76094ce75fe87db08c28689f0fb1da94f3d06c52aa1aa9...
# 8  76094ce75fe87db08c28689f0fb1da94f3d06c52aa1aa9...
# 9  4a394d5ba248f8f2a6704ff6e8b91bc58d99198cb820b1...
#
#                   sheet_name  entry_num file_type  \
# 0                        NaN          0       csv
# 1              General Notes          0      xlsx
# 2            Tribal Data Use          0      xlsx
# 3           Federal Data Use          0      xlsx
# 4      DOCKET_USBC-2018-0009          0      xlsx
# 5               Spreadsheets          0      xlsx
# ...

# %% [markdown]
# start looking for suspiciously empty cols
